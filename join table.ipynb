# %%
df_silv = pd.read_csv("D:\\prdp\\Data Science\\Live-Market\\Silver EFT Historical Data.csv")
df_silv = df_silv[["Date", "SilverETF"]]
df_silv.sample(5)
# Out:
#            Date  SilverETF
# 657  13-10-2023      68.69
# 981  23-06-2022      60.05
# 168  03-10-2025     139.76
# 623  04-12-2023      75.15
# 72   20-02-2026     236.62

# %%
df_eft = pd.read_csv("D:\\prdp\\Data Science\\Live-Market\\Correction.csv")

# %%
# Drop the blank old ETF columns
df_eft = df_eft.drop(
    columns=["ETF-Gold", "ETF-Silver"]
)

# Rename the new ETF columns to the original names
df_eft = df_eft.rename(
    columns={
        "ETF-Gold-New": "ETF-Gold",
        "ETF-Silver-New": "ETF-Silver"
    }
)

# %%
# Drop blank ETF columns
df_eft = df_eft.drop(
    columns=["ETF-Gold", "ETF-Silver"]
)

# Rename new ETF columns
df_eft = df_eft.rename(
    columns={
        "ETF-Gold-New": "ETF-Gold",
        "ETF-Silver-New": "ETF-Silver"
    }
)

# Save back to the SAME file
df_eft.to_csv(
    r"D:\prdp\Data Science\Live-Market\Correction.csv",
    index=False
)

print("Correction.csv updated successfully.")
# Out:
# Correction.csv updated successfully.
